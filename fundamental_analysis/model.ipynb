# %%
import yfinance as yf
import requests
import json
import re

# 获取公司简况
def get_company_overview(stock_code):
    stock = yf.Ticker(stock_code)
    info = stock.info
    overview = info.get('longBusinessSummary', 'No description available')
    return overview

# %%
# 示例运行
stock_code = "1113.HK"
proxy = 'http://127.0.0.1:10802'
# 获取简况
yf.set_config(proxy=proxy)
overview = get_company_overview(stock_code)
print(f"公司简介: {overview}...")  # 显示前200字符
# Out:
# 公司简介: CK Asset Holdings Limited operates as a property developer in Hong Kong, the Mainland, Singapore, the United Kingdom, continental Europe, Australia, and Canada. It is involved in the leasing of office, industrial, retail, residential, and other properties; property investment and development activities; and pub, and hotel and serviced suite operation businesses. The company also offers property and project management, finance, and property agency services, as well as invests in infrastructure and utility asset operation. The company was formerly known as Cheung Kong Property Holdings Limited and changed its name to CK Asset Holdings Limited in September 2017. CK Asset Holdings Limited was incorporated in 2015 and is headquartered in Central, Hong Kong....

# %%
# 调用Ollama QWQ-32B进行商业模式评估
def find_industry_mode(name,overview):
    url = "http://localhost:11434/api/generate"  # Ollama API端点
    prompt = f"""**任务**：请根据以下六项标准，评估 [{name}] 的商业模式。对每项标准，给出详细的评估，仅使用所提供的信息进行判断。如果信息不足或不清楚，明确说明该标准无法评估。不得推测或添加未明确提供的信息。
            **评估标准**：
            1. **行业和公司理解**：是否充分理解该公司所在行业及其运营模式？
            2. **重复性资本支出**：公司的重复性资本支出是否较低（即是否需要持续的大额资本投入）？
            3. **收入模式**：公司的收入模式是否以现金为主，较少依赖应收账款？
            4. **垄断程度**：公司是否具有一定的垄断地位或竞争优势，减少市场竞争？
            5. **定价能力**：公司是否能够自主定价并将成本增加转嫁给客户？
            6. **市场周期性**：公司的市场周期性是否较低，即利润和分红是否稳定可预测？

            **指令**：
            - 对每项标准，给出明确评估结果（例如“满足”、“不满足”或“无法判断”）。
            - 如果因信息不足无法评估某项标准，请说明：“由于信息不足，无法判断。”
            - 在评估完所有标准后，提供总结：
            - 如果所有标准都能清晰评估且满足要求，结论为：“商业模式完全可理解。”
            - 如果任一标准无法评估或不满足要求，结论为：“商业模式无法完全理解。”

            **重要提示**：仅基于以下提供的公司信息进行评估，严禁推测或臆断。

            **公司信息**：[{overview}]

            **评估**：
            - **标准 1**：[评估内容]
            - **标准 2**：[评估内容]
            - **标准 3**：[评估内容]
            - **标准 4**：[评估内容]
            - **标准 5**：[评估内容]
            - **标准 6**：[评估内容]

            **总结**：[基于评估的最终结论]"""
    payload = {
        "model": "qwen3:30b-a3b",
        "prompt": prompt,
        "stream": False
    }
    response = requests.post(url, json=payload)
    result = response.json()['response']
    return result

# %%
mode = find_industry_mode(stock_code,overview)
print(f"商业模式: {mode}")
# Out:
# 商业模式: <think>
# 好的，我现在要评估[1113.HK]的商业模式，也就是CK Asset Holdings Limited。根据提供的六个标准，我需要逐一分析每个标准是否满足，或者因为信息不足无法判断。
#
# 首先看标准1：行业和公司理解。公司信息显示他们是一家地产开发商，业务遍及多个地区，包括香港、中国大陆、新加坡、英国、欧洲大陆、澳大利亚和加拿大。他们涉及物业租赁、投资开发、酒店、餐厅运营，还有物业管理、金融和地产代理服务，以及基础设施和公用事业投资。公司成立于2015年，总部在港岛中环。从这些信息来看，我对他们的行业和运营模式有一定的了解，但可能不够详细。不过，至少知道他们属于房地产和相关服务行业，所以标准1应该满足。
#
# 标准2：重复性资本支出。地产开发通常需要大量资本投入，比如购买土地、建设物业等。但公司信息中没有提到具体的资本支出情况，比如每年的资本支出金额或是否持续大额投入。因此，可能无法判断，需要说明信息不足。
#
# 标准3：收入模式是否以现金为主，较少依赖应收账款。公司信息中没有提到收入的结构，比如现金销售比例或应收账款情况。因此，无法判断，需要说明信息不足。
#
# 标准4：垄断程度或竞争优势。公司信息中没有提到市场占有率、竞争优势或垄断地位，比如是否有专利、品牌优势或独特资源。因此，无法判断，信息不足。
#
# 标准5：定价能力。同样，公司信息中没有提到他们是否有能力自主定价或转嫁成本，比如是否能提高价格而不影响销售。因此，无法判断，信息不足。
#
# 标准6：市场周期性。房地产行业通常受经济周期影响较大，比如经济不好时需求下降。但公司信息中没有提到他们的业务是否受周期性影响，或者利润和分红是否稳定。因此，信息不足，无法判断。
#
# 总结的话，除了标准1外，其他五个标准都因为信息不足无法判断，所以结论应该是商业模式无法完全理解。
# </think>
#
# **评估**：
# - **标准 1**：满足。公司为多元化的地产开发商，业务涵盖物业租赁、投资开发、酒店及服务式公寓运营，并涉及物业管理、金融及基础设施投资，覆盖多个地区。其商业模式明确围绕房地产及相关服务展开。
# - **标准 2**：由于信息不足，无法判断。公司未提供具体资本支出数据或其重复性资本支出的规模和频率。
# - **标准 3**：由于信息不足，无法判断。未提及收入模式中现金占比或应收账款情况。
# - **标准 4**：由于信息不足，无法判断。未提供市场占有率、竞争壁垒或垄断性信息。
# - **标准 5**：由于信息不足，无法判断。未提及定价能力或成本转嫁机制。
# - **标准 6**：由于信息不足，无法判断。未说明业务受经济周期影响程度或利润稳定性。
#
# **总结**：商业模式无法完全理解。

# %%
# 调用Ollama QWQ-32B进行行业分类
def classify_industry(overview):
    url = "http://localhost:11434/api/generate"  # Ollama API端点
    prompt = f"请根据以下公司简介，分析并用简洁的语言回答：\n1. 主要业务类型（科技/制造/金融/能源/消费等）\n2. 经营模式（轻资产/重资产）\n3. 市场地位（垄断/寡头/充分竞争）\n4. 行业周期性（强周期/弱周期/非周期）\n\n公司简介：{overview}\n\n请用逗号分隔每个维度的结论，例如：科技,轻资产,充分竞争,弱周期"
    payload = {
        "model": "qwq:latest",
        "prompt": prompt,
        "stream": False
    }
    response = requests.post(url, json=payload)
    result = response.json()['response']
    
    # 处理结果，提取最终结论
    # 尝试查找最后一行包含逗号分隔的结论
    lines = result.strip().split('\n')
    for line in reversed(lines):
        # 查找符合"类型,类型,类型,类型"格式的行
        if line.count(',') == 3 and all(part.strip() for part in line.split(',')):
            return line.strip()
    
    # 如果没有找到符合格式的行，尝试使用正则表达式提取
    pattern = r'([^,\n]+,[^,\n]+,[^,\n]+,[^,\n]+)'
    matches = re.findall(pattern, result)
    if matches:
        return matches[-1].strip()
    
    # 如果仍然无法提取，返回原始结果并发出警告
    print("警告：无法提取格式化的行业分类结果")
    return result

def calculate_base_pe(company_type, discount_factor=0.6):
    """
    根据公司类型和折价系数计算基础PE值，使用有限状态机实现。
    
    参数:
    company_type (str): 公司类型，例如"消费,重资产,充分竞争,弱周期"
    discount_factor (float): 最终折价系数，默认0.6
    
    返回:
    float: 调整后的基础PE值
    """
    # 解析公司类型
    try:
        business_type, asset_model, market_status, cycle_type = company_type.split(',')
        business_type = business_type.strip()
        asset_model = asset_model.strip()
        market_status = market_status.strip()
        cycle_type = cycle_type.strip()
    except ValueError:
        raise ValueError("公司类型格式错误，应为'业务类型,经营模式,市场地位,行业周期性'")

    # 定义状态机初始值和调整系数
    base_pe = 0.0  # 初始PE
    state = 0      # 状态机状态

    # 状态转移逻辑
    while state <= 4:
        if state == 0:  # 状态0：设定基础PE（主要业务类型）
            if business_type == "科技":
                base_pe = 25
            elif business_type == "制造":
                base_pe = 15
            elif business_type == "金融":
                base_pe = 12
            elif business_type == "能源":
                base_pe = 15
            elif business_type == "消费":
                base_pe = 20
            else:
                raise ValueError(f"未知业务类型: {business_type}")
            state += 1

        elif state == 1:  # 状态1：经营模式调整
            if asset_model == "轻资产":
                base_pe *= 1.1
            elif asset_model == "重资产":
                base_pe *= 0.9
            else:
                raise ValueError(f"未知经营模式: {asset_model}")
            state += 1

        elif state == 2:  # 状态2：市场地位调整
            if market_status == "垄断":
                base_pe *= 1.1
            elif market_status == "寡头":
                base_pe *= 1.0
            elif market_status == "充分竞争":
                base_pe *= 0.9
            else:
                raise ValueError(f"未知市场地位: {market_status}")
            state += 1

        elif state == 3:  # 状态3：行业周期性调整
            if cycle_type == "非周期":
                base_pe *= 1.1
            elif cycle_type == "弱周期":
                base_pe *= 1.0
            elif cycle_type == "强周期":
                base_pe *= 0.9
            else:
                raise ValueError(f"未知行业周期性: {cycle_type}")
            state += 1

        elif state == 4:  # 状态4：应用折价系数
            base_pe *= discount_factor
            state += 1

    return base_pe

# %%
# 行业分类
analysis = classify_industry(overview)
print(f"公司类型: {analysis}")

# %%
base_pe = calculate_base_pe(analysis, discount_factor=0.8)
print(f"基础PE: {base_pe:.2f}")
# Out:
# 基础PE: 17.60

# %%
# 获取历史净利润增长率
def get_profit_growth_rate(stock_code, years=3):
    stock = yf.Ticker(stock_code)
    
    # 获取年度财务数据
    financials = stock.financials
    
    # 尝试获取净利润数据
    try:
        if 'Net Income' in financials.index:
            net_income = financials.loc['Net Income']
        elif 'Net Income Common Stockholders' in financials.index:
            net_income = financials.loc['Net Income Common Stockholders']
        else:
            # 如果找不到净利润相关指标，返回None
            print(f"无法找到{stock_code}的净利润数据")
            return None
        
        # 计算年度增长率
        growth_rates = []
        for i in range(len(net_income) - 1):
            if net_income.iloc[i+1] != 0:  # 避免除以零
                growth_rate = (net_income.iloc[i] - net_income.iloc[i+1]) / abs(net_income.iloc[i+1])
                growth_rates.append(growth_rate)
        
        # 如果数据不足years年，则使用所有可用数据
        available_years = min(years, len(growth_rates))
        if available_years == 0:
            print(f"没有足够的历史数据计算{stock_code}的增长率")
            return 0.05  # 默认5%增长率
            
        # 计算平均增长率
        avg_growth_rate = sum(growth_rates[:available_years]) / available_years
        return avg_growth_rate
        
    except Exception as e:
        print(f"计算{stock_code}增长率时出错: {e}")
        return 0.05  # 默认5%增长率

# 预测未来PE
def predict_future_pe(base_pe, growth_rate, years=3):
    """
    基于基础PE和增长率预测未来PE
    
    参数:
    base_pe (float): 基础PE值
    growth_rate (float): 年平均净利润增长率
    years (int): 预测年数
    
    返回:
    dict: 包含各年预测PE的字典
    """
    future_pes = {}
    
    # 增长率调整 - 高增长率适当折价，避免过度乐观
    adjusted_growth_rate = growth_rate
    if growth_rate > 0.3:
        adjusted_growth_rate = 0.3 + (growth_rate - 0.3) * 0.5  # 超过30%的部分打五折
    
    # 负增长率调整 - 避免过度悲观
    if growth_rate < -0.2:
        adjusted_growth_rate = -0.2 + (growth_rate + 0.2) * 0.5  # 低于-20%的部分打五折
    
    # 计算各年PE
    for year in range(1, years + 1):
        # PE随增长率变化，高增长对应高PE
        growth_factor = 1 + (adjusted_growth_rate * year)
        # 确保增长因子不会导致PE变为负数
        growth_factor = max(0.5, growth_factor)
        future_pes[f"Year_{year}"] = base_pe * growth_factor
    
    return future_pes

# %%
# 获取历史增长率
growth_rate = get_profit_growth_rate(stock_code)
print(f"历史年平均净利润增长率: {growth_rate:.2%}")

# 预测未来PE
future_pes = predict_future_pe(base_pe, growth_rate)
print("\n未来PE预测:")
for year, pe in future_pes.items():
    print(f"{year}: {pe:.2f}")

# 获取当前股价
stock = yf.Ticker(stock_code)
current_price = stock.info.get('currentPrice', None)
if current_price:
    # 获取最近的每股收益
    pe = stock.info.get('trailingPE', None)
    if pe and pe != 0:
        current_pe = pe
        print(f"\n当前股价: {current_price:.2f}, 当前PE: {current_pe:.2f}")
        
        # 估值分析
        avg_future_pe = sum(future_pes.values()) / len(future_pes)
        if current_pe < avg_future_pe * 0.8:
            valuation = "低估"
        elif current_pe > avg_future_pe * 1.2:
            valuation = "高估"
        else:
            valuation = "合理"
        
        print(f"三年平均预期PE: {avg_future_pe:.2f}, 估值状态: {valuation}")
    else:
        print("无法获取每股收益数据")
else:
    print("无法获取当前股价")
# Out:
# 历史年平均净利润增长率: 13.97%
#
# 未来PE预测:
# Year_1: 20.06
# Year_2: 22.52
# Year_3: 24.98
#
# 当前股价: 377.80, 当前PE: 20.86
# 三年平均预期PE: 22.52, 估值状态: 合理
